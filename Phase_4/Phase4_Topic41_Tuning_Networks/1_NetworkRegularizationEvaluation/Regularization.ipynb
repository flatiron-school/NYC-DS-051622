# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:200%;
#            font-family:Arial;letter-spacing:0.5px">
#
# <p width = 20%, style="padding: 10px;
#               color:white;">
# Neural Networks: Regularization
# </p>
# </div>
#
# Data Science Cohort Live NYC Jully 2022
# <p>Phase 4: Topic 41</p>
# <br>
# <br>
#
# <div align = "right">
# <img src="Images/flatiron-school-logo.png" align = "right" width="200"/>
# </div>

# %%
from sklearn.datasets import load_sample_images
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sns

from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Flatten # takes 2D input and turns into 1D array

import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Things to remember:

# %% [markdown]
# ## STEPS ##
#
# 1. Load Data
# 2. Define Keras Model
# 3. Compile Keras Model
# 4. Fit Keras Model
# 5. Evaluate Keras Model
# 6. Make Predictions

# %% [markdown]
# - The data and labels in `fit()` need to be numpy arrays, not `pandas` dfs.
# - Scaling your data will have a large impact on your model.
#    > For our traditional input features, we would use a scaler object. For images, as long as the minimum value is 0, we can simply divide through by the maximum pixel intensity.

# %% [markdown]
# #### Regularization
# - Retain complexity of neural network: many weights to learn interesting relationships
# - Make our weights less susceptible to overfitting
#
# **Getting neural networks to perform really well**

# %% [markdown]
# In neural networks, two main forms of regularization:
# - L2 Regularization (something familiar)
# - Dropout Regularization (something a little new)

# %% [markdown]
# **L2 Regularization**
#
# - Add penalty on weight **matrices**.
# $$ J \rightarrow J' $$
# $$ J = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) $$
# $$ J' = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) + \frac{\lambda}{2} \sum_{l=1}^L \lVert  W^{[l]}   \rVert_F^2 $$

# %% [markdown]
# where $F$ denotes the Frobenius norm.

# %% [markdown]
# Frobenius norm is square root of sum of of element-wise square:
# i.e.
# $$ \lVert  A   \rVert_F = \sqrt{\sum_{i,j} A_{ij}^2 }$$

# %%
import numpy as np
from numpy.linalg import norm

# %%
A = np.array([[1,2],[0,3]])
A
# Out:
# array([[1, 2],
#        [0, 3]])

# %%
norm(A, 'fro')
# Out:
# 3.7416573867739413

# %%
np.sqrt(1**2 + 0**2 + 2**2 + 3**2)
# Out:
# 3.7416573867739413

# %% [markdown]
# Modiied objective functon:
#
# $$ J' = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) + \frac{\lambda}{2} \sum_{l=1}^L \lVert  W^{[l]}   \rVert_F^2 $$

# %% [markdown]
# Regularization serves to penalize any particular weight from being too large:
# - smoothens/redistributes weights for each weight matrix
# - aids in generalization

# %% [markdown]
# L2 regularization: often known as weight decay
# - Perspective: gradient descent
# $$ J' = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) + \frac{\lambda}{2} \sum_{l=1}^L \lVert  W^{[l]}   \rVert_F^2 $$
# $$ W^{[l]} \rightarrow W^{[l]} - \alpha \frac{\partial J'}{\partial W^{[l]}} $$

# %% [markdown]
# $$ J = \sum_{i=1}^m \frac{1}{m}L(y_i, \hat{y}_i) $$
# $$ W^{[l]} \rightarrow \Big(W^{[l]}  - \alpha \frac{\lambda}{2 m}  W^{[l]} \Big) - \alpha \frac{\partial J}{\partial W^{[l]}}$$
#
# - At each iteration regularization tries to reduce magnitude of weight matrix.

# %% [markdown]
# #### Implementing L2 regularization in Keras

# %%
# creates keras regularizer object
from tensorflow.keras.regularizers import l2

# %% [markdown]
# L2 regularizer object takes in $\lambda$ parameter as argument

# %%
reg = l2(3e-3) # 1e-5 to .1

# %% [markdown]
# Implementing regularization to weights in Keras:
# - Dense(kernel_regularizer = __)
# - takes in string ('l2') or regularizer object

# %% [markdown]
# Less common but also used:
#
# - can apply regularization to bias terms
# - Dense(bias_regularizer = __)

# %%
# load in the data
(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()

x_train = x_train/255 # normalization
x_test = x_test/255

# Keras requires multi-class labels to be one-hot encoded
y_tr_one_hot = to_categorical(y_train)
y_tt_one_hot = to_categorical(y_test)

# %%
model_images = Sequential()
model_images.add(Flatten(input_shape=(28, 28))) # flattens each 28x28 image into a vector
model_images.add(Dense(32, activation='relu', kernel_regularizer = reg)) # take in regularizer
model_images.add(Dense(8, activation='relu', kernel_regularizer = reg))
model_images.add(Dense(10, activation='softmax')) # number of units = number of target classes
# Out:
# 2022-07-28 09:14:02.572912: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-28 09:14:02.573948: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
model_images.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'] )

# %%
# verbose=1 allows you to see the output.
# To see only the metrics at the end of each epoch, set verbose=2.
history_mnist = model_images.fit(x_train, y_tr_one_hot, epochs=50, batch_size= 32, validation_split = 0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 6s 126us/sample - loss: 0.7259 - accuracy: 0.8358 - val_loss: 0.4578 - val_accuracy: 0.9183
# Epoch 2/50
# 48000/48000 [==============================] - 5s 109us/sample - loss: 0.4453 - accuracy: 0.9218 - val_loss: 0.4008 - val_accuracy: 0.9339
# Epoch 3/50
# 48000/48000 [==============================] - 6s 117us/sample - loss: 0.3993 - accuracy: 0.9327 - val_loss: 0.3731 - val_accuracy: 0.9424
# Epoch 4/50
# 48000/48000 [==============================] - 6s 120us/sample - loss: 0.3704 - accuracy: 0.9395 - val_loss: 0.3572 - val_accuracy: 0.9423
# Epoch 5/50
# 48000/48000 [==============================] - 6s 124us/sample - loss: 0.3505 - accuracy: 0.9436 - val_loss: 0.3339 - val_accuracy: 0.9502
# Epoch 6/50
# 48000/48000 [==============================] - 6s 124us/sample - loss: 0.3352 - accuracy: 0.9457 - val_loss: 0.3228 - val_accuracy: 0.9507
# Epoch 7/50
# 48000/48000 [==============================] - 6s 122us/sample - loss: 0.3230 - accuracy: 0.9482 - val_loss: 0.3072 - val_accuracy: 0.9521
# Epoch 8/50
# 48000/48000 [==============================] - 6s 122us/sample - loss: 0.3108 - accuracy: 0.9505 - val_loss: 0.2958 - val_accuracy: 0.9577
# Epoch 9/50
# 48000/48000 [==============================] - 6s 130us/sample - loss: 0.3019 - accuracy: 0.9513 - val_loss: 0.3131 - val_accuracy: 0.9490
# Epoch 10/50
# 48000/48000 [==============================] - 6s 124us/sample - loss: 0.2954 - accuracy: 0.9521 - val_loss: 0.2834 - val_accuracy: 0.9585
# Epoch 11/50
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2887 - accuracy: 0.9540 - val_loss: 0.2829 - val_accuracy: 0.9569
# Epoch 12/50
# 48000/48000 [==============================] - 9s 182us/sample - loss: 0.2832 - accuracy: 0.9552 - val_loss: 0.2865 - val_accuracy: 0.9545
# Epoch 13/50
# 48000/48000 [==============================] - 6s 120us/sample - loss: 0.2772 - accuracy: 0.9546 - val_loss: 0.2683 - val_accuracy: 0.9585
# Epoch 14/50
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2716 - accuracy: 0.9565 - val_loss: 0.2747 - val_accuracy: 0.9568
# Epoch 15/50
# 48000/48000 [==============================] - 6s 120us/sample - loss: 0.2700 - accuracy: 0.9564 - val_loss: 0.2731 - val_accuracy: 0.9566
# Epoch 16/50
# 48000/48000 [==============================] - 6s 119us/sample - loss: 0.2639 - accuracy: 0.9569 - val_loss: 0.2725 - val_accuracy: 0.9563
# Epoch 17/50
# 48000/48000 [==============================] - 6s 119us/sample - loss: 0.2611 - accuracy: 0.9581 - val_loss: 0.2600 - val_accuracy: 0.9587
# Epoch 18/50
# 48000/48000 [==============================] - 6s 118us/sample - loss: 0.2582 - accuracy: 0.9585 - val_loss: 0.2564 - val_accuracy: 0.9607
# Epoch 19/50
# 48000/48000 [==============================] - 6s 120us/sample - loss: 0.2543 - accuracy: 0.9587 - val_loss: 0.2697 - val_accuracy: 0.9539
# Epoch 20/50
# 48000/48000 [==============================] - 6s 119us/sample - loss: 0.2546 - accuracy: 0.9578 - val_loss: 0.2579 - val_accuracy: 0.9578
# Epoch 21/50
# 48000/48000 [==============================] - 6s 122us/sample - loss: 0.2505 - accuracy: 0.9590 - val_loss: 0.2661 - val_accuracy: 0.9541
# Epoch 22/50
# 48000/48000 [==============================] - 6s 121us/sample - loss: 0.2490 - accuracy: 0.9586 - val_loss: 0.2431 - val_accuracy: 0.9620
# Epoch 23/50
# 48000/48000 [==============================] - 6s 128us/sample - loss: 0.2460 - accuracy: 0.9592 - val_loss: 0.2538 - val_accuracy: 0.9591
# Epoch 24/50
# 48000/48000 [==============================] - 6s 129us/sample - loss: 0.2437 - accuracy: 0.9597 - val_loss: 0.2509 - val_accuracy: 0.9589
# Epoch 25/50
# 48000/48000 [==============================] - 6s 129us/sample - loss: 0.2421 - accuracy: 0.9603 - val_loss: 0.2466 - val_accuracy: 0.9590
# Epoch 26/50
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.2397 - accuracy: 0.9598 - val_loss: 0.2529 - val_accuracy: 0.9591
# Epoch 27/50
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2391 - accuracy: 0.9606 - val_loss: 0.2388 - val_accuracy: 0.9603
# Epoch 28/50
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.2381 - accuracy: 0.9604 - val_loss: 0.2475 - val_accuracy: 0.9576
# Epoch 29/50
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.2358 - accuracy: 0.9613 - val_loss: 0.2442 - val_accuracy: 0.9599
# Epoch 30/50
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.2338 - accuracy: 0.9613 - val_loss: 0.2340 - val_accuracy: 0.9632
# Epoch 31/50
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2323 - accuracy: 0.9604 - val_loss: 0.2447 - val_accuracy: 0.9589
# Epoch 32/50
# 48000/48000 [==============================] - 6s 128us/sample - loss: 0.2315 - accuracy: 0.9617 - val_loss: 0.2348 - val_accuracy: 0.9597
# Epoch 33/50
# 48000/48000 [==============================] - 6s 124us/sample - loss: 0.2297 - accuracy: 0.9616 - val_loss: 0.2367 - val_accuracy: 0.9607
# Epoch 34/50
# 48000/48000 [==============================] - 6s 130us/sample - loss: 0.2278 - accuracy: 0.9616 - val_loss: 0.2441 - val_accuracy: 0.9574
# Epoch 35/50
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2261 - accuracy: 0.9620 - val_loss: 0.2336 - val_accuracy: 0.9608
# Epoch 36/50
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2239 - accuracy: 0.9629 - val_loss: 0.2294 - val_accuracy: 0.9617
# Epoch 37/50
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.2253 - accuracy: 0.9621 - val_loss: 0.2369 - val_accuracy: 0.9589
# Epoch 38/50
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2229 - accuracy: 0.9634 - val_loss: 0.2255 - val_accuracy: 0.9620
# Epoch 39/50
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.2216 - accuracy: 0.9629 - val_loss: 0.2196 - val_accuracy: 0.9643
# Epoch 40/50
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2196 - accuracy: 0.9636 - val_loss: 0.2307 - val_accuracy: 0.9603
# Epoch 41/50
# 48000/48000 [==============================] - 6s 127us/sample - loss: 0.2204 - accuracy: 0.9625 - val_loss: 0.2263 - val_accuracy: 0.9637
# Epoch 42/50
# 48000/48000 [==============================] - 6s 127us/sample - loss: 0.2187 - accuracy: 0.9632 - val_loss: 0.2307 - val_accuracy: 0.9581
# Epoch 43/50
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.2197 - accuracy: 0.9625 - val_loss: 0.2189 - val_accuracy: 0.9638
# Epoch 44/50
# 48000/48000 [==============================] - 6s 133us/sample - loss: 0.2163 - accuracy: 0.9639 - val_loss: 0.2193 - val_accuracy: 0.9643
# Epoch 45/50
# 48000/48000 [==============================] - 6s 128us/sample - loss: 0.2167 - accuracy: 0.9630 - val_loss: 0.2280 - val_accuracy: 0.9619
# Epoch 46/50
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.2178 - accuracy: 0.9630 - val_loss: 0.2270 - val_accuracy: 0.9583
# Epoch 47/50
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.2130 - accuracy: 0.9640 - val_loss: 0.2233 - val_accuracy: 0.9597
# Epoch 48/50
# 48000/48000 [==============================] - 6s 131us/sample - loss: 0.2145 - accuracy: 0.9621 - val_loss: 0.2314 - val_accuracy: 0.9594
# Epoch 49/50
# 48000/48000 [==============================] - 6s 134us/sample - loss: 0.2143 - accuracy: 0.9632 - val_loss: 0.2394 - val_accuracy: 0.9538
# Epoch 50/50
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.2132 - accuracy: 0.9644 - val_loss: 0.2135 - val_accuracy: 0.9646

# %%
# probability for each class
y_proba = model_images.predict(x_test)
y_proba
# Out:
# array([[1.4500866e-07, 2.0690342e-07, 2.3224133e-04, ..., 9.9931312e-01,
#         3.4238988e-07, 9.3214243e-05],
#        [3.5887337e-05, 2.0920718e-03, 9.8931259e-01, ..., 1.9705894e-06,
#         1.8258429e-03, 1.3445775e-10],
#        [4.6728925e-05, 9.9145210e-01, 1.3526254e-03, ..., 4.3298914e-03,
#         1.3715114e-03, 3.5796114e-05],
#        ...,
#        [1.7799248e-09, 7.2272371e-07, 1.9486350e-08, ..., 4.2832828e-05,
#         3.6416059e-05, 8.2038222e-03],
#        [4.4117623e-05, 6.9544177e-07, 1.2099167e-07, ..., 7.1023109e-08,
#         6.4764828e-03, 3.4581203e-04],
#        [3.5148533e-04, 3.7757300e-08, 1.4378286e-04, ..., 1.7140392e-08,
#         3.4550364e-06, 3.8347650e-08]], dtype=float32)

# %%
model_images.evaluate(x_test, y_tt_one_hot)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.20284137535095215, 0.9662]

# %%
train_mnist_history = pd.DataFrame(history_mnist.history)
train_mnist_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_mnist_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_mnist_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Better validation accuracy:
# - 94.5\% to 96.3\% with regularization
# - no overfitting

# %%
# argmax axis = -1 gets the column index of maximum probability for each row.
# column index corresponds to digit classes (numbers 0 -9)
predicted = np.argmax(y_proba, axis=-1)
predicted
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
cm_digits = confusion_matrix(y_test, predicted)
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_digits)

disp.plot(cmap=plt.cm.Blues)
plt.show()

# %% [markdown]
# Regularization:
# - key component to training deeper networks (tend to overfit without regularization)
# - learn higher order features, but don't overtrain on specifics.

# %%
deepermodel_images = Sequential()
deepermodel_images.add(Flatten(input_shape=(28, 28))) # flattens each 28x28 image into a vector
deepermodel_images.add(Dense(32, activation='relu', kernel_regularizer = reg)) # take in regularizer
deepermodel_images.add(Dense(16, activation='relu', kernel_regularizer = reg)) # add another layer
deepermodel_images.add(Dense(16, activation='relu', kernel_regularizer = reg)) # add another layer
deepermodel_images.add(Dense(10, activation='relu', kernel_regularizer = reg))
deepermodel_images.add(Dense(10, activation='softmax')) # number of units = number of target classes

deepermodel_images.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'] )

# %%
# will take a while
history_deepermnist = deepermodel_images.fit(x_train, y_tr_one_hot, epochs=200, batch_size= 32, validation_split = 0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.7966 - accuracy: 0.8229 - val_loss: 0.4835 - val_accuracy: 0.9298
# Epoch 2/200
# 48000/48000 [==============================] - 7s 150us/sample - loss: 0.4692 - accuracy: 0.9320 - val_loss: 0.4624 - val_accuracy: 0.9326
# Epoch 3/200
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.4226 - accuracy: 0.9420 - val_loss: 0.4041 - val_accuracy: 0.9449
# Epoch 4/200
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.3979 - accuracy: 0.9453 - val_loss: 0.3841 - val_accuracy: 0.9494
# Epoch 5/200
# 48000/48000 [==============================] - 7s 156us/sample - loss: 0.3769 - accuracy: 0.9492 - val_loss: 0.3587 - val_accuracy: 0.9567
# Epoch 6/200
# 48000/48000 [==============================] - 8s 159us/sample - loss: 0.3608 - accuracy: 0.9530 - val_loss: 0.3594 - val_accuracy: 0.9530
# Epoch 7/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.3518 - accuracy: 0.9532 - val_loss: 0.3383 - val_accuracy: 0.9569
# Epoch 8/200
# 48000/48000 [==============================] - 8s 169us/sample - loss: 0.3425 - accuracy: 0.9538 - val_loss: 0.3365 - val_accuracy: 0.9567
# Epoch 9/200
# 48000/48000 [==============================] - 9s 185us/sample - loss: 0.3346 - accuracy: 0.9551 - val_loss: 0.3369 - val_accuracy: 0.9535
# Epoch 10/200
# 48000/48000 [==============================] - 8s 162us/sample - loss: 0.3297 - accuracy: 0.9550 - val_loss: 0.3194 - val_accuracy: 0.9603
# Epoch 11/200
# 48000/48000 [==============================] - 8s 163us/sample - loss: 0.3225 - accuracy: 0.9562 - val_loss: 0.3139 - val_accuracy: 0.9619
# Epoch 12/200
# 48000/48000 [==============================] - 8s 168us/sample - loss: 0.3167 - accuracy: 0.9577 - val_loss: 0.3020 - val_accuracy: 0.9627
# Epoch 13/200
# 48000/48000 [==============================] - 8s 175us/sample - loss: 0.3162 - accuracy: 0.9567 - val_loss: 0.3340 - val_accuracy: 0.9492
# Epoch 14/200
# 48000/48000 [==============================] - 8s 168us/sample - loss: 0.3100 - accuracy: 0.9580 - val_loss: 0.3090 - val_accuracy: 0.9550
# Epoch 15/200
# 48000/48000 [==============================] - 8s 165us/sample - loss: 0.3066 - accuracy: 0.9581 - val_loss: 0.3125 - val_accuracy: 0.9578
# Epoch 16/200
# 48000/48000 [==============================] - 7s 150us/sample - loss: 0.3042 - accuracy: 0.9585 - val_loss: 0.3109 - val_accuracy: 0.9560
# Epoch 17/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.2971 - accuracy: 0.9601 - val_loss: 0.3029 - val_accuracy: 0.9572
# Epoch 18/200
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.2974 - accuracy: 0.9588 - val_loss: 0.3018 - val_accuracy: 0.9592
# Epoch 19/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2942 - accuracy: 0.9581 - val_loss: 0.2918 - val_accuracy: 0.9617
# Epoch 20/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.2905 - accuracy: 0.9597 - val_loss: 0.3138 - val_accuracy: 0.9570
# Epoch 21/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.2888 - accuracy: 0.9599 - val_loss: 0.3249 - val_accuracy: 0.9485
# Epoch 22/200
# 48000/48000 [==============================] - 8s 176us/sample - loss: 0.2875 - accuracy: 0.9598 - val_loss: 0.2950 - val_accuracy: 0.9571
# Epoch 23/200
# 48000/48000 [==============================] - 9s 184us/sample - loss: 0.2834 - accuracy: 0.9605 - val_loss: 0.2823 - val_accuracy: 0.9628
# Epoch 24/200
# 48000/48000 [==============================] - 8s 174us/sample - loss: 0.2819 - accuracy: 0.9615 - val_loss: 0.2836 - val_accuracy: 0.9607
# Epoch 25/200
# 48000/48000 [==============================] - 7s 152us/sample - loss: 0.2809 - accuracy: 0.9606 - val_loss: 0.2820 - val_accuracy: 0.9614
# Epoch 26/200
# 48000/48000 [==============================] - 8s 159us/sample - loss: 0.2772 - accuracy: 0.9609 - val_loss: 0.2835 - val_accuracy: 0.9593
# Epoch 27/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2781 - accuracy: 0.9609 - val_loss: 0.2765 - val_accuracy: 0.9615
# Epoch 28/200
# 48000/48000 [==============================] - 8s 165us/sample - loss: 0.2750 - accuracy: 0.9619 - val_loss: 0.2815 - val_accuracy: 0.9617
# Epoch 29/200
# 48000/48000 [==============================] - 8s 170us/sample - loss: 0.2736 - accuracy: 0.9617 - val_loss: 0.2842 - val_accuracy: 0.9588
# Epoch 30/200
# 48000/48000 [==============================] - 9s 183us/sample - loss: 0.2700 - accuracy: 0.9621 - val_loss: 0.2673 - val_accuracy: 0.9627
# Epoch 31/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2701 - accuracy: 0.9617 - val_loss: 0.2792 - val_accuracy: 0.9582
# Epoch 32/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.2699 - accuracy: 0.9617 - val_loss: 0.2954 - val_accuracy: 0.9547
# Epoch 33/200
# 48000/48000 [==============================] - 8s 158us/sample - loss: 0.2667 - accuracy: 0.9628 - val_loss: 0.2760 - val_accuracy: 0.9609
# Epoch 34/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2677 - accuracy: 0.9616 - val_loss: 0.2703 - val_accuracy: 0.9622
# Epoch 35/200
# 48000/48000 [==============================] - 11s 221us/sample - loss: 0.2642 - accuracy: 0.9628 - val_loss: 0.2789 - val_accuracy: 0.9566
# Epoch 36/200
# 48000/48000 [==============================] - 8s 166us/sample - loss: 0.2644 - accuracy: 0.9628 - val_loss: 0.2858 - val_accuracy: 0.9564
# Epoch 37/200
# 48000/48000 [==============================] - 8s 160us/sample - loss: 0.2623 - accuracy: 0.9626 - val_loss: 0.2719 - val_accuracy: 0.9612
# Epoch 38/200
# 48000/48000 [==============================] - 12s 243us/sample - loss: 0.2614 - accuracy: 0.9623 - val_loss: 0.2686 - val_accuracy: 0.9613
# Epoch 39/200
# 48000/48000 [==============================] - 15s 305us/sample - loss: 0.2600 - accuracy: 0.9629 - val_loss: 0.2711 - val_accuracy: 0.9609
# Epoch 40/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.2571 - accuracy: 0.9637 - val_loss: 0.2624 - val_accuracy: 0.9632
# Epoch 41/200
# 48000/48000 [==============================] - 7s 155us/sample - loss: 0.2592 - accuracy: 0.9622 - val_loss: 0.3002 - val_accuracy: 0.9508
# Epoch 42/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.2578 - accuracy: 0.9635 - val_loss: 0.2678 - val_accuracy: 0.9614
# Epoch 43/200
# 48000/48000 [==============================] - 8s 175us/sample - loss: 0.2575 - accuracy: 0.9633 - val_loss: 0.2608 - val_accuracy: 0.9607
# Epoch 44/200
# 48000/48000 [==============================] - 7s 155us/sample - loss: 0.2541 - accuracy: 0.9632 - val_loss: 0.2557 - val_accuracy: 0.9635
# Epoch 45/200
# 48000/48000 [==============================] - 8s 164us/sample - loss: 0.2545 - accuracy: 0.9629 - val_loss: 0.2581 - val_accuracy: 0.9629
# Epoch 46/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2537 - accuracy: 0.9640 - val_loss: 0.2694 - val_accuracy: 0.9601
# Epoch 47/200
# 48000/48000 [==============================] - 7s 150us/sample - loss: 0.2534 - accuracy: 0.9636 - val_loss: 0.2536 - val_accuracy: 0.9643
# Epoch 48/200
# 48000/48000 [==============================] - 7s 155us/sample - loss: 0.2519 - accuracy: 0.9634 - val_loss: 0.2727 - val_accuracy: 0.9569
# Epoch 49/200
# 48000/48000 [==============================] - 8s 156us/sample - loss: 0.2504 - accuracy: 0.9637 - val_loss: 0.2663 - val_accuracy: 0.9605
# Epoch 50/200
# 48000/48000 [==============================] - 7s 153us/sample - loss: 0.2487 - accuracy: 0.9636 - val_loss: 0.2639 - val_accuracy: 0.9597
# Epoch 51/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2519 - accuracy: 0.9627 - val_loss: 0.2798 - val_accuracy: 0.9538
# Epoch 52/200
# 48000/48000 [==============================] - 7s 153us/sample - loss: 0.2487 - accuracy: 0.9639 - val_loss: 0.2681 - val_accuracy: 0.9603
# Epoch 53/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2473 - accuracy: 0.9640 - val_loss: 0.2662 - val_accuracy: 0.9615
# Epoch 54/200
# 48000/48000 [==============================] - 8s 163us/sample - loss: 0.2453 - accuracy: 0.9651 - val_loss: 0.2545 - val_accuracy: 0.9607
# Epoch 55/200
# 48000/48000 [==============================] - 9s 178us/sample - loss: 0.2480 - accuracy: 0.9638 - val_loss: 0.2531 - val_accuracy: 0.9643
# Epoch 56/200
# 48000/48000 [==============================] - 9s 178us/sample - loss: 0.2475 - accuracy: 0.9636 - val_loss: 0.2575 - val_accuracy: 0.9594
# Epoch 57/200
# 48000/48000 [==============================] - 8s 174us/sample - loss: 0.2443 - accuracy: 0.9645 - val_loss: 0.2578 - val_accuracy: 0.9628
# Epoch 58/200
# 48000/48000 [==============================] - 8s 167us/sample - loss: 0.2468 - accuracy: 0.9636 - val_loss: 0.2990 - val_accuracy: 0.9476
# Epoch 59/200
# 48000/48000 [==============================] - 8s 173us/sample - loss: 0.2440 - accuracy: 0.9649 - val_loss: 0.2556 - val_accuracy: 0.9607
# Epoch 60/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2428 - accuracy: 0.9639 - val_loss: 0.2551 - val_accuracy: 0.9626
# Epoch 61/200
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.2443 - accuracy: 0.9644 - val_loss: 0.2612 - val_accuracy: 0.9595
# Epoch 62/200
# 48000/48000 [==============================] - 8s 165us/sample - loss: 0.2411 - accuracy: 0.9643 - val_loss: 0.2461 - val_accuracy: 0.9650
# Epoch 63/200
# 48000/48000 [==============================] - 8s 175us/sample - loss: 0.2429 - accuracy: 0.9651 - val_loss: 0.2503 - val_accuracy: 0.9636
# Epoch 64/200
# 48000/48000 [==============================] - 8s 166us/sample - loss: 0.2419 - accuracy: 0.9648 - val_loss: 0.2805 - val_accuracy: 0.9536
# Epoch 65/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2454 - accuracy: 0.9634 - val_loss: 0.2425 - val_accuracy: 0.9655
# Epoch 66/200
# 48000/48000 [==============================] - 10s 212us/sample - loss: 0.2415 - accuracy: 0.9642 - val_loss: 0.2444 - val_accuracy: 0.9637
# Epoch 67/200
# 48000/48000 [==============================] - 20s 411us/sample - loss: 0.2414 - accuracy: 0.9638 - val_loss: 0.2498 - val_accuracy: 0.9626
# Epoch 68/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2406 - accuracy: 0.9643 - val_loss: 0.2585 - val_accuracy: 0.9608
# Epoch 69/200
# 48000/48000 [==============================] - 8s 175us/sample - loss: 0.2442 - accuracy: 0.9630 - val_loss: 0.2400 - val_accuracy: 0.9653
# Epoch 70/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2390 - accuracy: 0.9646 - val_loss: 0.2596 - val_accuracy: 0.9576
# Epoch 71/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2393 - accuracy: 0.9651 - val_loss: 0.2374 - val_accuracy: 0.9644
# Epoch 72/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2390 - accuracy: 0.9643 - val_loss: 0.2532 - val_accuracy: 0.9597
# Epoch 73/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.2402 - accuracy: 0.9640 - val_loss: 0.2449 - val_accuracy: 0.9619
# Epoch 74/200
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.2405 - accuracy: 0.9642 - val_loss: 0.2541 - val_accuracy: 0.9617
# Epoch 75/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2406 - accuracy: 0.9632 - val_loss: 0.2450 - val_accuracy: 0.9643
# Epoch 76/200
# 48000/48000 [==============================] - 8s 169us/sample - loss: 0.2384 - accuracy: 0.9651 - val_loss: 0.2549 - val_accuracy: 0.9597
# Epoch 77/200
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2390 - accuracy: 0.9641 - val_loss: 0.2450 - val_accuracy: 0.9616
# Epoch 78/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2367 - accuracy: 0.9654 - val_loss: 0.2470 - val_accuracy: 0.9631
# Epoch 79/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2377 - accuracy: 0.9650 - val_loss: 0.2420 - val_accuracy: 0.9610
# Epoch 80/200
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2355 - accuracy: 0.9657 - val_loss: 0.2472 - val_accuracy: 0.9638
# Epoch 81/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2373 - accuracy: 0.9650 - val_loss: 0.2479 - val_accuracy: 0.9627
# Epoch 82/200
# 48000/48000 [==============================] - 11s 229us/sample - loss: 0.2350 - accuracy: 0.9650 - val_loss: 0.2617 - val_accuracy: 0.9591
# Epoch 83/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2382 - accuracy: 0.9631 - val_loss: 0.2491 - val_accuracy: 0.9603
# Epoch 84/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2358 - accuracy: 0.9644 - val_loss: 0.2604 - val_accuracy: 0.9582
# Epoch 85/200
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2345 - accuracy: 0.9641 - val_loss: 0.2493 - val_accuracy: 0.9637
# Epoch 86/200
# 48000/48000 [==============================] - 8s 175us/sample - loss: 0.2376 - accuracy: 0.9644 - val_loss: 0.2422 - val_accuracy: 0.9631
# Epoch 87/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2347 - accuracy: 0.9654 - val_loss: 0.2550 - val_accuracy: 0.9585
# Epoch 88/200
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2357 - accuracy: 0.9648 - val_loss: 0.2519 - val_accuracy: 0.9602
# Epoch 89/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2338 - accuracy: 0.9654 - val_loss: 0.2351 - val_accuracy: 0.9660
# Epoch 90/200
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2333 - accuracy: 0.9657 - val_loss: 0.2629 - val_accuracy: 0.9567
# Epoch 91/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.2341 - accuracy: 0.9652 - val_loss: 0.2455 - val_accuracy: 0.9627
# Epoch 92/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2313 - accuracy: 0.9659 - val_loss: 0.2428 - val_accuracy: 0.9646
# Epoch 93/200
# 48000/48000 [==============================] - 9s 180us/sample - loss: 0.2362 - accuracy: 0.9640 - val_loss: 0.2309 - val_accuracy: 0.9673
# Epoch 94/200
# 48000/48000 [==============================] - 8s 177us/sample - loss: 0.2321 - accuracy: 0.9644 - val_loss: 0.2492 - val_accuracy: 0.9588
# Epoch 95/200
# 48000/48000 [==============================] - 8s 175us/sample - loss: 0.2317 - accuracy: 0.9661 - val_loss: 0.2438 - val_accuracy: 0.9640
# Epoch 96/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2322 - accuracy: 0.9659 - val_loss: 0.2341 - val_accuracy: 0.9653
# Epoch 97/200
# 48000/48000 [==============================] - 8s 175us/sample - loss: 0.2300 - accuracy: 0.9656 - val_loss: 0.2451 - val_accuracy: 0.9641
# Epoch 98/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2329 - accuracy: 0.9654 - val_loss: 0.2369 - val_accuracy: 0.9650
# Epoch 99/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2326 - accuracy: 0.9649 - val_loss: 0.2428 - val_accuracy: 0.9638
# Epoch 100/200
# 48000/48000 [==============================] - 529s 11ms/sample - loss: 0.2300 - accuracy: 0.9665 - val_loss: 0.2392 - val_accuracy: 0.9631
# Epoch 101/200
# 48000/48000 [==============================] - 9s 188us/sample - loss: 0.2317 - accuracy: 0.9651 - val_loss: 0.2497 - val_accuracy: 0.9620
# Epoch 102/200
# 48000/48000 [==============================] - 10s 198us/sample - loss: 0.2315 - accuracy: 0.9654 - val_loss: 0.2456 - val_accuracy: 0.9602
# Epoch 103/200
# 48000/48000 [==============================] - 8s 168us/sample - loss: 0.2313 - accuracy: 0.9662 - val_loss: 0.2489 - val_accuracy: 0.9586
# Epoch 104/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2297 - accuracy: 0.9652 - val_loss: 0.2455 - val_accuracy: 0.9603
# Epoch 105/200
# 48000/48000 [==============================] - 9s 184us/sample - loss: 0.2302 - accuracy: 0.9647 - val_loss: 0.2362 - val_accuracy: 0.9621
# Epoch 106/200
# 48000/48000 [==============================] - 8s 172us/sample - loss: 0.2310 - accuracy: 0.9654 - val_loss: 0.2366 - val_accuracy: 0.9632
# Epoch 107/200
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.2309 - accuracy: 0.9651 - val_loss: 0.2373 - val_accuracy: 0.9636
# Epoch 108/200
# 48000/48000 [==============================] - 11s 227us/sample - loss: 0.2298 - accuracy: 0.9648 - val_loss: 0.2601 - val_accuracy: 0.9564
# Epoch 109/200
# 48000/48000 [==============================] - 15s 307us/sample - loss: 0.2319 - accuracy: 0.9640 - val_loss: 0.2811 - val_accuracy: 0.9498
# Epoch 110/200
# 48000/48000 [==============================] - 10s 207us/sample - loss: 0.2284 - accuracy: 0.9662 - val_loss: 0.2507 - val_accuracy: 0.9604
# Epoch 111/200
# 48000/48000 [==============================] - 8s 159us/sample - loss: 0.2315 - accuracy: 0.9652 - val_loss: 0.2433 - val_accuracy: 0.9618
# Epoch 112/200
# 48000/48000 [==============================] - 13s 265us/sample - loss: 0.2271 - accuracy: 0.9669 - val_loss: 0.2395 - val_accuracy: 0.9625
# Epoch 113/200
# 48000/48000 [==============================] - 10s 212us/sample - loss: 0.2277 - accuracy: 0.9661 - val_loss: 0.2390 - val_accuracy: 0.9620
# Epoch 114/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2316 - accuracy: 0.9647 - val_loss: 0.2493 - val_accuracy: 0.9559
# Epoch 115/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.2270 - accuracy: 0.9665 - val_loss: 0.2477 - val_accuracy: 0.9613
# Epoch 116/200
# 48000/48000 [==============================] - 10s 202us/sample - loss: 0.2279 - accuracy: 0.9655 - val_loss: 0.2398 - val_accuracy: 0.9644
# Epoch 117/200
# 48000/48000 [==============================] - 8s 164us/sample - loss: 0.2268 - accuracy: 0.9670 - val_loss: 0.2396 - val_accuracy: 0.9610
# Epoch 118/200
# 48000/48000 [==============================] - 9s 190us/sample - loss: 0.2254 - accuracy: 0.9662 - val_loss: 0.2363 - val_accuracy: 0.9635
# Epoch 119/200
# 48000/48000 [==============================] - 10s 210us/sample - loss: 0.2282 - accuracy: 0.9656 - val_loss: 0.2355 - val_accuracy: 0.9638
# Epoch 120/200
# 48000/48000 [==============================] - 20s 424us/sample - loss: 0.2271 - accuracy: 0.9659 - val_loss: 0.2425 - val_accuracy: 0.9653
# Epoch 121/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2279 - accuracy: 0.9657 - val_loss: 0.2388 - val_accuracy: 0.9617
# Epoch 122/200
# 48000/48000 [==============================] - 7s 155us/sample - loss: 0.2256 - accuracy: 0.9667 - val_loss: 0.2376 - val_accuracy: 0.9623
# Epoch 123/200
# 48000/48000 [==============================] - 9s 186us/sample - loss: 0.2263 - accuracy: 0.9659 - val_loss: 0.2574 - val_accuracy: 0.9564
# Epoch 124/200
# 48000/48000 [==============================] - 8s 158us/sample - loss: 0.2262 - accuracy: 0.9657 - val_loss: 0.2348 - val_accuracy: 0.9641
# Epoch 125/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2257 - accuracy: 0.9657 - val_loss: 0.2500 - val_accuracy: 0.9592
# Epoch 126/200
# 48000/48000 [==============================] - 7s 153us/sample - loss: 0.2269 - accuracy: 0.9651 - val_loss: 0.2362 - val_accuracy: 0.9628
# Epoch 127/200
# 48000/48000 [==============================] - 12s 241us/sample - loss: 0.2236 - accuracy: 0.9667 - val_loss: 0.2280 - val_accuracy: 0.9653
# Epoch 128/200
# 48000/48000 [==============================] - 11s 235us/sample - loss: 0.2238 - accuracy: 0.9670 - val_loss: 0.2362 - val_accuracy: 0.9637
# Epoch 129/200
# 48000/48000 [==============================] - 16s 338us/sample - loss: 0.2276 - accuracy: 0.9660 - val_loss: 0.2317 - val_accuracy: 0.9625
# Epoch 130/200
# 48000/48000 [==============================] - 8s 170us/sample - loss: 0.2256 - accuracy: 0.9656 - val_loss: 0.2343 - val_accuracy: 0.9633
# Epoch 131/200
# 48000/48000 [==============================] - 8s 169us/sample - loss: 0.2273 - accuracy: 0.9658 - val_loss: 0.2456 - val_accuracy: 0.9611
# Epoch 132/200
# 48000/48000 [==============================] - 8s 166us/sample - loss: 0.2242 - accuracy: 0.9665 - val_loss: 0.2265 - val_accuracy: 0.9665
# Epoch 133/200
# 48000/48000 [==============================] - 8s 162us/sample - loss: 0.2250 - accuracy: 0.9659 - val_loss: 0.2325 - val_accuracy: 0.9632
# Epoch 134/200
# 48000/48000 [==============================] - 11s 219us/sample - loss: 0.2229 - accuracy: 0.9673 - val_loss: 0.2541 - val_accuracy: 0.9581
# Epoch 135/200
# 48000/48000 [==============================] - 8s 175us/sample - loss: 0.2270 - accuracy: 0.9654 - val_loss: 0.2620 - val_accuracy: 0.9548
# Epoch 136/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.2235 - accuracy: 0.9662 - val_loss: 0.2310 - val_accuracy: 0.9638
# Epoch 137/200
# 48000/48000 [==============================] - 8s 164us/sample - loss: 0.2239 - accuracy: 0.9661 - val_loss: 0.2384 - val_accuracy: 0.9603
# Epoch 138/200
# 48000/48000 [==============================] - 12s 251us/sample - loss: 0.2266 - accuracy: 0.9657 - val_loss: 0.2259 - val_accuracy: 0.9659
# Epoch 139/200
# 48000/48000 [==============================] - 22s 450us/sample - loss: 0.2233 - accuracy: 0.9670 - val_loss: 0.2376 - val_accuracy: 0.9624
# Epoch 140/200
# 48000/48000 [==============================] - 9s 195us/sample - loss: 0.2227 - accuracy: 0.9658 - val_loss: 0.2471 - val_accuracy: 0.9606
# Epoch 141/200
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.2258 - accuracy: 0.9653 - val_loss: 0.2468 - val_accuracy: 0.9596
# Epoch 142/200
# 48000/48000 [==============================] - 9s 179us/sample - loss: 0.2242 - accuracy: 0.9666 - val_loss: 0.2284 - val_accuracy: 0.9653
# Epoch 143/200
# 48000/48000 [==============================] - 9s 179us/sample - loss: 0.2210 - accuracy: 0.9670 - val_loss: 0.2356 - val_accuracy: 0.9638
# Epoch 144/200
# 48000/48000 [==============================] - 8s 166us/sample - loss: 0.2212 - accuracy: 0.9668 - val_loss: 0.2331 - val_accuracy: 0.9633
# Epoch 145/200
# 48000/48000 [==============================] - 12s 256us/sample - loss: 0.2245 - accuracy: 0.9654 - val_loss: 0.2247 - val_accuracy: 0.9658
# Epoch 146/200
# 48000/48000 [==============================] - 12s 242us/sample - loss: 0.2195 - accuracy: 0.9669 - val_loss: 0.2354 - val_accuracy: 0.9636
# Epoch 147/200
# 48000/48000 [==============================] - 8s 172us/sample - loss: 0.2230 - accuracy: 0.9668 - val_loss: 0.2267 - val_accuracy: 0.9653
# Epoch 148/200
# 48000/48000 [==============================] - 8s 159us/sample - loss: 0.2201 - accuracy: 0.9668 - val_loss: 0.2287 - val_accuracy: 0.9646
# Epoch 149/200
# 48000/48000 [==============================] - 9s 197us/sample - loss: 0.2218 - accuracy: 0.9664 - val_loss: 0.2356 - val_accuracy: 0.9623
# Epoch 150/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2201 - accuracy: 0.9671 - val_loss: 0.2355 - val_accuracy: 0.9613
# Epoch 151/200
# 48000/48000 [==============================] - 10s 214us/sample - loss: 0.2231 - accuracy: 0.9658 - val_loss: 0.2353 - val_accuracy: 0.9638
# Epoch 152/200
# 48000/48000 [==============================] - 11s 224us/sample - loss: 0.2191 - accuracy: 0.9672 - val_loss: 0.2286 - val_accuracy: 0.9665
# Epoch 153/200
# 48000/48000 [==============================] - 9s 193us/sample - loss: 0.2207 - accuracy: 0.9675 - val_loss: 0.2189 - val_accuracy: 0.9679
# Epoch 154/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.2204 - accuracy: 0.9674 - val_loss: 0.2295 - val_accuracy: 0.9641
# Epoch 155/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.2179 - accuracy: 0.9670 - val_loss: 0.2229 - val_accuracy: 0.9682
# Epoch 156/200
# 48000/48000 [==============================] - 8s 159us/sample - loss: 0.2215 - accuracy: 0.9658 - val_loss: 0.2447 - val_accuracy: 0.9631
# Epoch 157/200
# 48000/48000 [==============================] - 13s 279us/sample - loss: 0.2179 - accuracy: 0.9673 - val_loss: 0.2333 - val_accuracy: 0.9617
# Epoch 158/200
# 48000/48000 [==============================] - 10s 218us/sample - loss: 0.2199 - accuracy: 0.9669 - val_loss: 0.2318 - val_accuracy: 0.9650
# Epoch 159/200
# 48000/48000 [==============================] - 7s 152us/sample - loss: 0.2203 - accuracy: 0.9665 - val_loss: 0.2438 - val_accuracy: 0.9604
# Epoch 160/200
# 48000/48000 [==============================] - 10s 202us/sample - loss: 0.2206 - accuracy: 0.9669 - val_loss: 0.2271 - val_accuracy: 0.9643
# Epoch 161/200
# 48000/48000 [==============================] - 8s 156us/sample - loss: 0.2181 - accuracy: 0.9671 - val_loss: 0.2307 - val_accuracy: 0.9650
# Epoch 162/200
# 48000/48000 [==============================] - 7s 153us/sample - loss: 0.2207 - accuracy: 0.9663 - val_loss: 0.2425 - val_accuracy: 0.9594
# Epoch 163/200
# 48000/48000 [==============================] - 7s 150us/sample - loss: 0.2192 - accuracy: 0.9672 - val_loss: 0.2422 - val_accuracy: 0.9592
# Epoch 164/200
# 48000/48000 [==============================] - 9s 181us/sample - loss: 0.2179 - accuracy: 0.9667 - val_loss: 0.2347 - val_accuracy: 0.9620
# Epoch 165/200
# 48000/48000 [==============================] - 8s 166us/sample - loss: 0.2184 - accuracy: 0.9666 - val_loss: 0.2390 - val_accuracy: 0.9613
# Epoch 166/200
# 48000/48000 [==============================] - 9s 190us/sample - loss: 0.2201 - accuracy: 0.9666 - val_loss: 0.2381 - val_accuracy: 0.9620
# Epoch 167/200
# 48000/48000 [==============================] - 8s 164us/sample - loss: 0.2189 - accuracy: 0.9673 - val_loss: 0.2288 - val_accuracy: 0.9641
# Epoch 168/200
# 48000/48000 [==============================] - 9s 188us/sample - loss: 0.2177 - accuracy: 0.9665 - val_loss: 0.2291 - val_accuracy: 0.9647
# Epoch 169/200
# 48000/48000 [==============================] - 8s 165us/sample - loss: 0.2199 - accuracy: 0.9666 - val_loss: 0.2341 - val_accuracy: 0.9637
# Epoch 170/200
# 48000/48000 [==============================] - 9s 180us/sample - loss: 0.2197 - accuracy: 0.9670 - val_loss: 0.2287 - val_accuracy: 0.9652
# Epoch 171/200
# 48000/48000 [==============================] - 14s 289us/sample - loss: 0.2181 - accuracy: 0.9670 - val_loss: 0.2537 - val_accuracy: 0.9552
# Epoch 172/200
# 48000/48000 [==============================] - 13s 274us/sample - loss: 0.2197 - accuracy: 0.9664 - val_loss: 0.2315 - val_accuracy: 0.9630
# Epoch 173/200
# 48000/48000 [==============================] - 13s 274us/sample - loss: 0.2167 - accuracy: 0.9674 - val_loss: 0.2465 - val_accuracy: 0.9607
# Epoch 174/200
# 48000/48000 [==============================] - 8s 164us/sample - loss: 0.2174 - accuracy: 0.9671 - val_loss: 0.2218 - val_accuracy: 0.9676
# Epoch 175/200
# 48000/48000 [==============================] - 8s 165us/sample - loss: 0.2191 - accuracy: 0.9669 - val_loss: 0.2269 - val_accuracy: 0.9663
# Epoch 176/200
# 48000/48000 [==============================] - 7s 156us/sample - loss: 0.2181 - accuracy: 0.9665 - val_loss: 0.2464 - val_accuracy: 0.9599
# Epoch 177/200
# 48000/48000 [==============================] - 8s 174us/sample - loss: 0.2169 - accuracy: 0.9675 - val_loss: 0.2399 - val_accuracy: 0.9600
# Epoch 178/200
# 48000/48000 [==============================] - 7s 153us/sample - loss: 0.2181 - accuracy: 0.9673 - val_loss: 0.2430 - val_accuracy: 0.9618
# Epoch 179/200
# 48000/48000 [==============================] - 9s 183us/sample - loss: 0.2176 - accuracy: 0.9671 - val_loss: 0.2348 - val_accuracy: 0.9633
# Epoch 180/200
# 48000/48000 [==============================] - 9s 196us/sample - loss: 0.2165 - accuracy: 0.9679 - val_loss: 0.2220 - val_accuracy: 0.9677
# Epoch 181/200
# 48000/48000 [==============================] - 8s 172us/sample - loss: 0.2158 - accuracy: 0.9682 - val_loss: 0.2476 - val_accuracy: 0.9599
# Epoch 182/200
# 48000/48000 [==============================] - 7s 155us/sample - loss: 0.2204 - accuracy: 0.9663 - val_loss: 0.2363 - val_accuracy: 0.9625
# Epoch 183/200
# 48000/48000 [==============================] - 9s 189us/sample - loss: 0.2144 - accuracy: 0.9684 - val_loss: 0.2225 - val_accuracy: 0.9654
# Epoch 184/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2190 - accuracy: 0.9675 - val_loss: 0.2231 - val_accuracy: 0.9663
# Epoch 185/200
# 48000/48000 [==============================] - 8s 156us/sample - loss: 0.2154 - accuracy: 0.9686 - val_loss: 0.2202 - val_accuracy: 0.9690
# Epoch 186/200
# 48000/48000 [==============================] - 10s 210us/sample - loss: 0.2175 - accuracy: 0.9663 - val_loss: 0.2385 - val_accuracy: 0.9638
# Epoch 187/200
# 48000/48000 [==============================] - 8s 158us/sample - loss: 0.2161 - accuracy: 0.9673 - val_loss: 0.2388 - val_accuracy: 0.9599
# Epoch 188/200
# 48000/48000 [==============================] - 8s 160us/sample - loss: 0.2157 - accuracy: 0.9671 - val_loss: 0.2382 - val_accuracy: 0.9605
# Epoch 189/200
# 48000/48000 [==============================] - 7s 152us/sample - loss: 0.2147 - accuracy: 0.9674 - val_loss: 0.2332 - val_accuracy: 0.9653
# Epoch 190/200
# 48000/48000 [==============================] - 10s 198us/sample - loss: 0.2160 - accuracy: 0.9678 - val_loss: 0.2266 - val_accuracy: 0.9662
# Epoch 191/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2188 - accuracy: 0.9663 - val_loss: 0.2586 - val_accuracy: 0.9536
# Epoch 192/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.2147 - accuracy: 0.9683 - val_loss: 0.2331 - val_accuracy: 0.9636
# Epoch 193/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2157 - accuracy: 0.9679 - val_loss: 0.2555 - val_accuracy: 0.9544
# Epoch 194/200
# 48000/48000 [==============================] - 8s 171us/sample - loss: 0.2169 - accuracy: 0.9669 - val_loss: 0.2334 - val_accuracy: 0.9653
# Epoch 195/200
# 48000/48000 [==============================] - 11s 236us/sample - loss: 0.2171 - accuracy: 0.9669 - val_loss: 0.2242 - val_accuracy: 0.9662
# Epoch 196/200
# 48000/48000 [==============================] - 11s 233us/sample - loss: 0.2144 - accuracy: 0.9678 - val_loss: 0.2277 - val_accuracy: 0.9668
# Epoch 197/200
# 48000/48000 [==============================] - 12s 241us/sample - loss: 0.2165 - accuracy: 0.9665 - val_loss: 0.2438 - val_accuracy: 0.9586
# Epoch 198/200
# 48000/48000 [==============================] - 9s 195us/sample - loss: 0.2143 - accuracy: 0.9673 - val_loss: 0.2361 - val_accuracy: 0.9615
# Epoch 199/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.2179 - accuracy: 0.9669 - val_loss: 0.2263 - val_accuracy: 0.9663
# Epoch 200/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.2151 - accuracy: 0.9676 - val_loss: 0.2404 - val_accuracy: 0.9621

# %%
#evaluate test accuracy
deepermodel_images.evaluate(x_test, y_tt_one_hot)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.2370602029800415, 0.9607]

# %%
train_deepmnist_history = pd.DataFrame(history_deepermnist.history)
train_deepmnist_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_deepmnist_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_deepmnist_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Not overfitting even while adding much more complexity:
# - in this case, not gaining much either

# %% [markdown]
# To do better:
# - try a different regularization technique
# - may need to think harder about network architecture

# %% [markdown]
# #### Dropout Regularization
# - Architecture based strategy.
#
# On each forward/backprop iteration:
# - given layer with dropout
# - shut off activations to randomly selected nodes in layer

# %% [markdown]
# ![drop_out](images/drop_out.png)

# %% [markdown]
# <img src = "Images/dropout_network.gif" >

# %% [markdown]
# - Set $p^{[l]}$  uniform probability of node dropout for given layer
# - each train cycle: kills different activations

# %% [markdown]
# Dead nodes dont contribute to weight updates in backprop.

# %% [markdown]
# after many train cycles: have learned weights:
# - contributions from many different networks learning different things

# %% [markdown]
# <img src = "Images/Deeper_network.jpg">

# %% [markdown]
# Validation/test phase:
# - use all nodes and learned weights.
# - make prediction.

# %% [markdown]
# **Why it works as regularization**
# - network learns not to trust in any one subset of weights: unlikely any particular weight subset gets too big.
# - distributes weights in way that is robust to network noise (random dropout): generalizes well.

# %% [markdown]
# #### Dropout in Keras
#
# - Simply add it as though it were a layer. It will apply to the immediately preceding layer.

# %%
from tensorflow.keras.layers import Dropout

# %% [markdown]
# Dropout() takes in the dropout probability as a constructor argument:
# - Dropout($p$) after some of the hidden layers.
# - $p \in [0.2, 0.5]$ as good range to try.

# %%
from tensorflow.keras.optimizers import Adam
opt = Adam(learning_rate=0.003, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

# %% [markdown]
# **Define model**

# %%
model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.2)) # dropout on previous activations
model.add(Dense(12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dropout(0.1)) # dropout
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(10, activation ='softmax'))

# compile model
model.compile(optimizer=opt, 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Some tips:
# - Dropout earlier in network or inputs. Don't put on final layers.
# - Try faster learning rates in optimizer

# %%
# will take a while
history_dropoutmnist = model.fit(x_train, y_tr_one_hot, epochs=200, batch_size= 32, validation_split = 0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
# 48000/48000 [==============================] - 8s 163us/sample - loss: 0.8490 - accuracy: 0.7217 - val_loss: 0.4003 - val_accuracy: 0.8946
# Epoch 2/200
# 48000/48000 [==============================] - 7s 153us/sample - loss: 0.5539 - accuracy: 0.8379 - val_loss: 0.3565 - val_accuracy: 0.9045
# Epoch 3/200
# 48000/48000 [==============================] - 8s 162us/sample - loss: 0.5030 - accuracy: 0.8562 - val_loss: 0.2974 - val_accuracy: 0.9239
# Epoch 4/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.4722 - accuracy: 0.8655 - val_loss: 0.2873 - val_accuracy: 0.9249
# Epoch 5/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.4492 - accuracy: 0.8712 - val_loss: 0.2900 - val_accuracy: 0.9202
# Epoch 6/200
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.4322 - accuracy: 0.8788 - val_loss: 0.2736 - val_accuracy: 0.9289
# Epoch 7/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.4246 - accuracy: 0.8798 - val_loss: 0.2621 - val_accuracy: 0.9330
# Epoch 8/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.4139 - accuracy: 0.8816 - val_loss: 0.2582 - val_accuracy: 0.9323
# Epoch 9/200
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.4045 - accuracy: 0.8835 - val_loss: 0.2541 - val_accuracy: 0.9335
# Epoch 10/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.3963 - accuracy: 0.8877 - val_loss: 0.2603 - val_accuracy: 0.9320
# Epoch 11/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.3948 - accuracy: 0.8878 - val_loss: 0.2645 - val_accuracy: 0.9342
# Epoch 12/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.3873 - accuracy: 0.8896 - val_loss: 0.2487 - val_accuracy: 0.9361
# Epoch 13/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.3804 - accuracy: 0.8920 - val_loss: 0.2532 - val_accuracy: 0.9373
# Epoch 14/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.3798 - accuracy: 0.8916 - val_loss: 0.2414 - val_accuracy: 0.9390
# Epoch 15/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.3731 - accuracy: 0.8934 - val_loss: 0.2482 - val_accuracy: 0.9373
# Epoch 16/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.3734 - accuracy: 0.8923 - val_loss: 0.2443 - val_accuracy: 0.9377
# Epoch 17/200
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.3673 - accuracy: 0.8953 - val_loss: 0.2514 - val_accuracy: 0.9331
# Epoch 18/200
# 48000/48000 [==============================] - 7s 155us/sample - loss: 0.3615 - accuracy: 0.8976 - val_loss: 0.2356 - val_accuracy: 0.9392
# Epoch 19/200
# 48000/48000 [==============================] - 8s 156us/sample - loss: 0.3560 - accuracy: 0.8983 - val_loss: 0.2487 - val_accuracy: 0.9376
# Epoch 20/200
# 48000/48000 [==============================] - 7s 153us/sample - loss: 0.3568 - accuracy: 0.8992 - val_loss: 0.2520 - val_accuracy: 0.9352
# Epoch 21/200
# 48000/48000 [==============================] - 8s 158us/sample - loss: 0.3547 - accuracy: 0.9001 - val_loss: 0.2400 - val_accuracy: 0.9392
# Epoch 22/200
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.3540 - accuracy: 0.8991 - val_loss: 0.2370 - val_accuracy: 0.9380
# Epoch 23/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.3484 - accuracy: 0.9007 - val_loss: 0.2316 - val_accuracy: 0.9378
# Epoch 24/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3460 - accuracy: 0.9004 - val_loss: 0.2439 - val_accuracy: 0.9369
# Epoch 25/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3447 - accuracy: 0.9005 - val_loss: 0.2434 - val_accuracy: 0.9396
# Epoch 26/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.3429 - accuracy: 0.9020 - val_loss: 0.2344 - val_accuracy: 0.9400
# Epoch 27/200
# 48000/48000 [==============================] - 7s 135us/sample - loss: 0.3453 - accuracy: 0.9026 - val_loss: 0.2347 - val_accuracy: 0.9398
# Epoch 28/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3427 - accuracy: 0.9028 - val_loss: 0.2319 - val_accuracy: 0.9422
# Epoch 29/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3411 - accuracy: 0.9028 - val_loss: 0.2534 - val_accuracy: 0.9337
# Epoch 30/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3421 - accuracy: 0.9020 - val_loss: 0.2319 - val_accuracy: 0.9396
# Epoch 31/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3388 - accuracy: 0.9035 - val_loss: 0.2430 - val_accuracy: 0.9398
# Epoch 32/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3387 - accuracy: 0.9046 - val_loss: 0.2396 - val_accuracy: 0.9371
# Epoch 33/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3420 - accuracy: 0.9029 - val_loss: 0.2451 - val_accuracy: 0.9388
# Epoch 34/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3359 - accuracy: 0.9036 - val_loss: 0.2266 - val_accuracy: 0.9404
# Epoch 35/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3323 - accuracy: 0.9045 - val_loss: 0.2429 - val_accuracy: 0.9388
# Epoch 36/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3365 - accuracy: 0.9045 - val_loss: 0.2283 - val_accuracy: 0.9403
# Epoch 37/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.3387 - accuracy: 0.9040 - val_loss: 0.2427 - val_accuracy: 0.9412
# Epoch 38/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.3361 - accuracy: 0.9049 - val_loss: 0.2317 - val_accuracy: 0.9412
# Epoch 39/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.3312 - accuracy: 0.9062 - val_loss: 0.2325 - val_accuracy: 0.9413
# Epoch 40/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3336 - accuracy: 0.9037 - val_loss: 0.2280 - val_accuracy: 0.9413
# Epoch 41/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3302 - accuracy: 0.9052 - val_loss: 0.2256 - val_accuracy: 0.9433
# Epoch 42/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.3281 - accuracy: 0.9057 - val_loss: 0.2413 - val_accuracy: 0.9367
# Epoch 43/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3336 - accuracy: 0.9050 - val_loss: 0.2308 - val_accuracy: 0.9409
# Epoch 44/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3312 - accuracy: 0.9066 - val_loss: 0.2301 - val_accuracy: 0.9433
# Epoch 45/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.3215 - accuracy: 0.9084 - val_loss: 0.2301 - val_accuracy: 0.9392
# Epoch 46/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3201 - accuracy: 0.9082 - val_loss: 0.2323 - val_accuracy: 0.9442
# Epoch 47/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3245 - accuracy: 0.9080 - val_loss: 0.2311 - val_accuracy: 0.9431
# Epoch 48/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3263 - accuracy: 0.9064 - val_loss: 0.2254 - val_accuracy: 0.9411
# Epoch 49/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3270 - accuracy: 0.9061 - val_loss: 0.2401 - val_accuracy: 0.9382
# Epoch 50/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3245 - accuracy: 0.9065 - val_loss: 0.2392 - val_accuracy: 0.9412
# Epoch 51/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3235 - accuracy: 0.9067 - val_loss: 0.2200 - val_accuracy: 0.9446
# Epoch 52/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3204 - accuracy: 0.9075 - val_loss: 0.2185 - val_accuracy: 0.9419
# Epoch 53/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3260 - accuracy: 0.9047 - val_loss: 0.2333 - val_accuracy: 0.9389
# Epoch 54/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3161 - accuracy: 0.9096 - val_loss: 0.2375 - val_accuracy: 0.9384
# Epoch 55/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3138 - accuracy: 0.9082 - val_loss: 0.2334 - val_accuracy: 0.9393
# Epoch 56/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.3129 - accuracy: 0.9099 - val_loss: 0.2362 - val_accuracy: 0.9383
# Epoch 57/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.3157 - accuracy: 0.9091 - val_loss: 0.2312 - val_accuracy: 0.9413
# Epoch 58/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3130 - accuracy: 0.9106 - val_loss: 0.2295 - val_accuracy: 0.9414
# Epoch 59/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3161 - accuracy: 0.9099 - val_loss: 0.2336 - val_accuracy: 0.9382
# Epoch 60/200
# 48000/48000 [==============================] - 7s 135us/sample - loss: 0.3131 - accuracy: 0.9099 - val_loss: 0.2252 - val_accuracy: 0.9433
# Epoch 61/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3168 - accuracy: 0.9087 - val_loss: 0.2377 - val_accuracy: 0.9396
# Epoch 62/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.3141 - accuracy: 0.9090 - val_loss: 0.2439 - val_accuracy: 0.9380
# Epoch 63/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3177 - accuracy: 0.9091 - val_loss: 0.2241 - val_accuracy: 0.9435
# Epoch 64/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3183 - accuracy: 0.9093 - val_loss: 0.2241 - val_accuracy: 0.9406
# Epoch 65/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.3091 - accuracy: 0.9116 - val_loss: 0.2332 - val_accuracy: 0.9392
# Epoch 66/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3095 - accuracy: 0.9108 - val_loss: 0.2210 - val_accuracy: 0.9431
# Epoch 67/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3116 - accuracy: 0.9110 - val_loss: 0.2251 - val_accuracy: 0.9413
# Epoch 68/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.3120 - accuracy: 0.9094 - val_loss: 0.2284 - val_accuracy: 0.9427
# Epoch 69/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.3160 - accuracy: 0.9101 - val_loss: 0.2274 - val_accuracy: 0.9408
# Epoch 70/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3061 - accuracy: 0.9117 - val_loss: 0.2283 - val_accuracy: 0.9420
# Epoch 71/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3055 - accuracy: 0.9120 - val_loss: 0.2453 - val_accuracy: 0.9397
# Epoch 72/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3064 - accuracy: 0.9131 - val_loss: 0.2324 - val_accuracy: 0.9398
# Epoch 73/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3113 - accuracy: 0.9097 - val_loss: 0.2278 - val_accuracy: 0.9411
# Epoch 74/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3068 - accuracy: 0.9111 - val_loss: 0.2317 - val_accuracy: 0.9430
# Epoch 75/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.3083 - accuracy: 0.9119 - val_loss: 0.2298 - val_accuracy: 0.9398
# Epoch 76/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3087 - accuracy: 0.9103 - val_loss: 0.2276 - val_accuracy: 0.9429
# Epoch 77/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3022 - accuracy: 0.9130 - val_loss: 0.2397 - val_accuracy: 0.9385
# Epoch 78/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3039 - accuracy: 0.9124 - val_loss: 0.2324 - val_accuracy: 0.9408
# Epoch 79/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3133 - accuracy: 0.9086 - val_loss: 0.2272 - val_accuracy: 0.9441
# Epoch 80/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3053 - accuracy: 0.9116 - val_loss: 0.2222 - val_accuracy: 0.9445
# Epoch 81/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.3027 - accuracy: 0.9127 - val_loss: 0.2323 - val_accuracy: 0.9401
# Epoch 82/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3081 - accuracy: 0.9118 - val_loss: 0.2329 - val_accuracy: 0.9406
# Epoch 83/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.3052 - accuracy: 0.9110 - val_loss: 0.2294 - val_accuracy: 0.9407
# Epoch 84/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.3014 - accuracy: 0.9134 - val_loss: 0.2384 - val_accuracy: 0.9391
# Epoch 85/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.3097 - accuracy: 0.9101 - val_loss: 0.2448 - val_accuracy: 0.9378
# Epoch 86/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.3014 - accuracy: 0.9142 - val_loss: 0.2336 - val_accuracy: 0.9424
# Epoch 87/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3020 - accuracy: 0.9137 - val_loss: 0.2401 - val_accuracy: 0.9394
# Epoch 88/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3017 - accuracy: 0.9138 - val_loss: 0.2310 - val_accuracy: 0.9428
# Epoch 89/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3009 - accuracy: 0.9132 - val_loss: 0.2378 - val_accuracy: 0.9398
# Epoch 90/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3028 - accuracy: 0.9129 - val_loss: 0.2317 - val_accuracy: 0.9417
# Epoch 91/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3072 - accuracy: 0.9117 - val_loss: 0.2382 - val_accuracy: 0.9402
# Epoch 92/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.3007 - accuracy: 0.9137 - val_loss: 0.2443 - val_accuracy: 0.9413
# Epoch 93/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2983 - accuracy: 0.9137 - val_loss: 0.2443 - val_accuracy: 0.9397
# Epoch 94/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3047 - accuracy: 0.9116 - val_loss: 0.2185 - val_accuracy: 0.9435
# Epoch 95/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.2994 - accuracy: 0.9136 - val_loss: 0.2318 - val_accuracy: 0.9425
# Epoch 96/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3017 - accuracy: 0.9123 - val_loss: 0.2314 - val_accuracy: 0.9419
# Epoch 97/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.2962 - accuracy: 0.9145 - val_loss: 0.2277 - val_accuracy: 0.9423
# Epoch 98/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3013 - accuracy: 0.9129 - val_loss: 0.2248 - val_accuracy: 0.9423
# Epoch 99/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3016 - accuracy: 0.9138 - val_loss: 0.2309 - val_accuracy: 0.9405
# Epoch 100/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.3001 - accuracy: 0.9134 - val_loss: 0.2345 - val_accuracy: 0.9408
# Epoch 101/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3049 - accuracy: 0.9109 - val_loss: 0.2320 - val_accuracy: 0.9398
# Epoch 102/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.3043 - accuracy: 0.9121 - val_loss: 0.2275 - val_accuracy: 0.9433
# Epoch 103/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.2989 - accuracy: 0.9122 - val_loss: 0.2298 - val_accuracy: 0.9396
# Epoch 104/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2948 - accuracy: 0.9146 - val_loss: 0.2407 - val_accuracy: 0.9397
# Epoch 105/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2979 - accuracy: 0.9158 - val_loss: 0.2253 - val_accuracy: 0.9409
# Epoch 106/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2992 - accuracy: 0.9130 - val_loss: 0.2269 - val_accuracy: 0.9423
# Epoch 107/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.3030 - accuracy: 0.9116 - val_loss: 0.2204 - val_accuracy: 0.9434
# Epoch 108/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2946 - accuracy: 0.9132 - val_loss: 0.2373 - val_accuracy: 0.9412
# Epoch 109/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.3007 - accuracy: 0.9139 - val_loss: 0.2320 - val_accuracy: 0.9391
# Epoch 110/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2984 - accuracy: 0.9147 - val_loss: 0.2221 - val_accuracy: 0.9423
# Epoch 111/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.2954 - accuracy: 0.9146 - val_loss: 0.2335 - val_accuracy: 0.9383
# Epoch 112/200
# 48000/48000 [==============================] - 7s 152us/sample - loss: 0.2941 - accuracy: 0.9151 - val_loss: 0.2352 - val_accuracy: 0.9388
# Epoch 113/200
# 48000/48000 [==============================] - 8s 166us/sample - loss: 0.2942 - accuracy: 0.9150 - val_loss: 0.2284 - val_accuracy: 0.9422
# Epoch 114/200
# 48000/48000 [==============================] - 8s 162us/sample - loss: 0.3001 - accuracy: 0.9115 - val_loss: 0.2269 - val_accuracy: 0.9433
# Epoch 115/200
# 48000/48000 [==============================] - 8s 160us/sample - loss: 0.2941 - accuracy: 0.9146 - val_loss: 0.2263 - val_accuracy: 0.9437
# Epoch 116/200
# 48000/48000 [==============================] - 7s 152us/sample - loss: 0.2971 - accuracy: 0.9144 - val_loss: 0.2369 - val_accuracy: 0.9401
# Epoch 117/200
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.2959 - accuracy: 0.9139 - val_loss: 0.2423 - val_accuracy: 0.9380
# Epoch 118/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2944 - accuracy: 0.9148 - val_loss: 0.2270 - val_accuracy: 0.9412
# Epoch 119/200
# 48000/48000 [==============================] - 7s 150us/sample - loss: 0.3005 - accuracy: 0.9130 - val_loss: 0.2317 - val_accuracy: 0.9408
# Epoch 120/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2927 - accuracy: 0.9151 - val_loss: 0.2467 - val_accuracy: 0.9371
# Epoch 121/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2968 - accuracy: 0.9142 - val_loss: 0.2350 - val_accuracy: 0.9385
# Epoch 122/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2985 - accuracy: 0.9134 - val_loss: 0.2421 - val_accuracy: 0.9359
# Epoch 123/200
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.2998 - accuracy: 0.9136 - val_loss: 0.2286 - val_accuracy: 0.9398
# Epoch 124/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2938 - accuracy: 0.9153 - val_loss: 0.2204 - val_accuracy: 0.9413
# Epoch 125/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2934 - accuracy: 0.9140 - val_loss: 0.2216 - val_accuracy: 0.9430
# Epoch 126/200
# 48000/48000 [==============================] - 8s 167us/sample - loss: 0.2952 - accuracy: 0.9145 - val_loss: 0.2345 - val_accuracy: 0.9407
# Epoch 127/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2932 - accuracy: 0.9156 - val_loss: 0.2293 - val_accuracy: 0.9419
# Epoch 128/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2975 - accuracy: 0.9133 - val_loss: 0.2335 - val_accuracy: 0.9398
# Epoch 129/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.2982 - accuracy: 0.9136 - val_loss: 0.2208 - val_accuracy: 0.9436
# Epoch 130/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2936 - accuracy: 0.9138 - val_loss: 0.2215 - val_accuracy: 0.9429
# Epoch 131/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.2929 - accuracy: 0.9148 - val_loss: 0.2268 - val_accuracy: 0.9418
# Epoch 132/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.2911 - accuracy: 0.9153 - val_loss: 0.2208 - val_accuracy: 0.9449
# Epoch 133/200
# 48000/48000 [==============================] - 7s 137us/sample - loss: 0.2910 - accuracy: 0.9166 - val_loss: 0.2253 - val_accuracy: 0.9459
# Epoch 134/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.2951 - accuracy: 0.9136 - val_loss: 0.2244 - val_accuracy: 0.9433
# Epoch 135/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2918 - accuracy: 0.9149 - val_loss: 0.2332 - val_accuracy: 0.9412
# Epoch 136/200
# 48000/48000 [==============================] - 7s 153us/sample - loss: 0.2919 - accuracy: 0.9151 - val_loss: 0.2309 - val_accuracy: 0.9410
# Epoch 137/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2978 - accuracy: 0.9131 - val_loss: 0.2381 - val_accuracy: 0.9430
# Epoch 138/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2889 - accuracy: 0.9159 - val_loss: 0.2318 - val_accuracy: 0.9406
# Epoch 139/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2890 - accuracy: 0.9159 - val_loss: 0.2326 - val_accuracy: 0.9407
# Epoch 140/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.2881 - accuracy: 0.9159 - val_loss: 0.2262 - val_accuracy: 0.9429
# Epoch 141/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2928 - accuracy: 0.9138 - val_loss: 0.2261 - val_accuracy: 0.9417
# Epoch 142/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.2888 - accuracy: 0.9157 - val_loss: 0.2368 - val_accuracy: 0.9394
# Epoch 143/200
# 48000/48000 [==============================] - 7s 155us/sample - loss: 0.2871 - accuracy: 0.9168 - val_loss: 0.2368 - val_accuracy: 0.9393
# Epoch 144/200
# 48000/48000 [==============================] - 8s 166us/sample - loss: 0.2916 - accuracy: 0.9152 - val_loss: 0.2403 - val_accuracy: 0.9400
# Epoch 145/200
# 48000/48000 [==============================] - 8s 164us/sample - loss: 0.2907 - accuracy: 0.9156 - val_loss: 0.2306 - val_accuracy: 0.9417
# Epoch 146/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2966 - accuracy: 0.9150 - val_loss: 0.2329 - val_accuracy: 0.9410
# Epoch 147/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2930 - accuracy: 0.9153 - val_loss: 0.2337 - val_accuracy: 0.9400
# Epoch 148/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2914 - accuracy: 0.9167 - val_loss: 0.2293 - val_accuracy: 0.9417
# Epoch 149/200
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.2828 - accuracy: 0.9181 - val_loss: 0.2351 - val_accuracy: 0.9403
# Epoch 150/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2934 - accuracy: 0.9153 - val_loss: 0.2314 - val_accuracy: 0.9425
# Epoch 151/200
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.2923 - accuracy: 0.9150 - val_loss: 0.2250 - val_accuracy: 0.9418
# Epoch 152/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2897 - accuracy: 0.9160 - val_loss: 0.2353 - val_accuracy: 0.9409
# Epoch 153/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2883 - accuracy: 0.9160 - val_loss: 0.2346 - val_accuracy: 0.9394
# Epoch 154/200
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.2909 - accuracy: 0.9149 - val_loss: 0.2497 - val_accuracy: 0.9404
# Epoch 155/200
# 48000/48000 [==============================] - 7s 144us/sample - loss: 0.2867 - accuracy: 0.9169 - val_loss: 0.2353 - val_accuracy: 0.9373
# Epoch 156/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2879 - accuracy: 0.9157 - val_loss: 0.2258 - val_accuracy: 0.9412
# Epoch 157/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.2913 - accuracy: 0.9159 - val_loss: 0.2457 - val_accuracy: 0.9390
# Epoch 158/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2852 - accuracy: 0.9169 - val_loss: 0.2332 - val_accuracy: 0.9457
# Epoch 159/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2893 - accuracy: 0.9166 - val_loss: 0.2336 - val_accuracy: 0.9391
# Epoch 160/200
# 48000/48000 [==============================] - 7s 154us/sample - loss: 0.2874 - accuracy: 0.9158 - val_loss: 0.2511 - val_accuracy: 0.9384
# Epoch 161/200
# 48000/48000 [==============================] - 8s 168us/sample - loss: 0.2868 - accuracy: 0.9171 - val_loss: 0.2299 - val_accuracy: 0.9404
# Epoch 162/200
# 48000/48000 [==============================] - 8s 173us/sample - loss: 0.2939 - accuracy: 0.9143 - val_loss: 0.2320 - val_accuracy: 0.9419
# Epoch 163/200
# 48000/48000 [==============================] - 8s 158us/sample - loss: 0.2889 - accuracy: 0.9161 - val_loss: 0.2376 - val_accuracy: 0.9392
# Epoch 164/200
# 48000/48000 [==============================] - 8s 160us/sample - loss: 0.2833 - accuracy: 0.9164 - val_loss: 0.2354 - val_accuracy: 0.9430
# Epoch 165/200
# 48000/48000 [==============================] - 7s 143us/sample - loss: 0.2842 - accuracy: 0.9166 - val_loss: 0.2469 - val_accuracy: 0.9425
# Epoch 166/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2900 - accuracy: 0.9145 - val_loss: 0.2328 - val_accuracy: 0.9402
# Epoch 167/200
# 48000/48000 [==============================] - 7s 152us/sample - loss: 0.2903 - accuracy: 0.9165 - val_loss: 0.2402 - val_accuracy: 0.9391
# Epoch 168/200
# 48000/48000 [==============================] - 7s 150us/sample - loss: 0.2860 - accuracy: 0.9167 - val_loss: 0.2465 - val_accuracy: 0.9373
# Epoch 169/200
# 48000/48000 [==============================] - 8s 162us/sample - loss: 0.2826 - accuracy: 0.9166 - val_loss: 0.2341 - val_accuracy: 0.9399
# Epoch 170/200
# 48000/48000 [==============================] - 7s 156us/sample - loss: 0.2873 - accuracy: 0.9161 - val_loss: 0.2514 - val_accuracy: 0.9377
# Epoch 171/200
# 48000/48000 [==============================] - 7s 150us/sample - loss: 0.2907 - accuracy: 0.9134 - val_loss: 0.2377 - val_accuracy: 0.9416
# Epoch 172/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2927 - accuracy: 0.9152 - val_loss: 0.2390 - val_accuracy: 0.9398
# Epoch 173/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2907 - accuracy: 0.9153 - val_loss: 0.2333 - val_accuracy: 0.9418
# Epoch 174/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2878 - accuracy: 0.9173 - val_loss: 0.2322 - val_accuracy: 0.9425
# Epoch 175/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2812 - accuracy: 0.9179 - val_loss: 0.2314 - val_accuracy: 0.9410
# Epoch 176/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.2881 - accuracy: 0.9159 - val_loss: 0.2314 - val_accuracy: 0.9424
# Epoch 177/200
# 48000/48000 [==============================] - 6s 135us/sample - loss: 0.2815 - accuracy: 0.9180 - val_loss: 0.2315 - val_accuracy: 0.9419
# Epoch 178/200
# 48000/48000 [==============================] - 7s 138us/sample - loss: 0.2816 - accuracy: 0.9178 - val_loss: 0.2260 - val_accuracy: 0.9410
# Epoch 179/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2824 - accuracy: 0.9159 - val_loss: 0.2527 - val_accuracy: 0.9368
# Epoch 180/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2911 - accuracy: 0.9157 - val_loss: 0.2391 - val_accuracy: 0.9414
# Epoch 181/200
# 48000/48000 [==============================] - 7s 136us/sample - loss: 0.2888 - accuracy: 0.9158 - val_loss: 0.2430 - val_accuracy: 0.9405
# Epoch 182/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2906 - accuracy: 0.9153 - val_loss: 0.2442 - val_accuracy: 0.9384
# Epoch 183/200
# 48000/48000 [==============================] - 7s 142us/sample - loss: 0.2860 - accuracy: 0.9166 - val_loss: 0.2432 - val_accuracy: 0.9386
# Epoch 184/200
# 48000/48000 [==============================] - 8s 157us/sample - loss: 0.2887 - accuracy: 0.9166 - val_loss: 0.2383 - val_accuracy: 0.9417
# Epoch 185/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2899 - accuracy: 0.9175 - val_loss: 0.2381 - val_accuracy: 0.9421
# Epoch 186/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.2875 - accuracy: 0.9169 - val_loss: 0.2390 - val_accuracy: 0.9406
# Epoch 187/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.2820 - accuracy: 0.9180 - val_loss: 0.2362 - val_accuracy: 0.9424
# Epoch 188/200
# 48000/48000 [==============================] - 7s 145us/sample - loss: 0.2885 - accuracy: 0.9151 - val_loss: 0.2438 - val_accuracy: 0.9391
# Epoch 189/200
# 48000/48000 [==============================] - 6s 132us/sample - loss: 0.2869 - accuracy: 0.9174 - val_loss: 0.2507 - val_accuracy: 0.9412
# Epoch 190/200
# 48000/48000 [==============================] - 7s 147us/sample - loss: 0.2868 - accuracy: 0.9163 - val_loss: 0.2387 - val_accuracy: 0.9421
# Epoch 191/200
# 48000/48000 [==============================] - 7s 149us/sample - loss: 0.2825 - accuracy: 0.9181 - val_loss: 0.2415 - val_accuracy: 0.9397
# Epoch 192/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2858 - accuracy: 0.9168 - val_loss: 0.2429 - val_accuracy: 0.9379
# Epoch 193/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2934 - accuracy: 0.9153 - val_loss: 0.2451 - val_accuracy: 0.9383
# Epoch 194/200
# 48000/48000 [==============================] - 7s 148us/sample - loss: 0.2863 - accuracy: 0.9176 - val_loss: 0.2363 - val_accuracy: 0.9425
# Epoch 195/200
# 48000/48000 [==============================] - 7s 146us/sample - loss: 0.2922 - accuracy: 0.9152 - val_loss: 0.2487 - val_accuracy: 0.9372
# Epoch 196/200
# 48000/48000 [==============================] - 7s 151us/sample - loss: 0.2828 - accuracy: 0.9172 - val_loss: 0.2443 - val_accuracy: 0.9380
# Epoch 197/200
# 48000/48000 [==============================] - 7s 141us/sample - loss: 0.2920 - accuracy: 0.9155 - val_loss: 0.2406 - val_accuracy: 0.9395
# Epoch 198/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2857 - accuracy: 0.9156 - val_loss: 0.2562 - val_accuracy: 0.9362
# Epoch 199/200
# 48000/48000 [==============================] - 7s 139us/sample - loss: 0.2814 - accuracy: 0.9184 - val_loss: 0.2332 - val_accuracy: 0.9417
# Epoch 200/200
# 48000/48000 [==============================] - 7s 140us/sample - loss: 0.2839 - accuracy: 0.9175 - val_loss: 0.2544 - val_accuracy: 0.9404

# %% [markdown]
# Accuracy on train set will be lower in any given cycle:
# - some activation killed randomly on training.
#
# Performance on validation will be high:
# - uses full network with learned weights for validation

# %% [markdown]
# Not overtraining despite high model capacity:
# - many hidden layers

# %%
train_dropoutmnist_history = pd.DataFrame(history_dropoutmnist.history)
train_dropoutmnist_history.index.name = 'epochs'

col_list = ['loss', 'val_loss']
train_dropoutmnist_history[col_list].plot()
plt.ylabel('Categorical cross entropy')
plt.title('Training loss history')
plt.show()

# %%
col_list = ['accuracy', 'val_accuracy']
train_dropoutmnist_history[col_list].plot()
plt.ylabel('Accuracy')
plt.title('Training loss history')
plt.show()

# %% [markdown]
# Evaluate on test set.

# %%
model.evaluate(x_test, y_tt_one_hot, verbose =0)
# Out:
# [0.2676965738534927, 0.9342]

# %% [markdown]
# #### Dropout regularization in conjunction with L2:
#
# - can be used to train very deep networks
# - model complex relationships without overfitting
# - works best in these cases with a lot of data

# %% [markdown]
# Next up:
# - doing much better with a more suitable network architecture
# - Convolutional Neural Networks (CNNs)
